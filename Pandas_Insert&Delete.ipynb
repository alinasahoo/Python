# %% [markdown]
# <a href="https://colab.research.google.com/github/alinasahoo/Python/blob/main/Pandas_Insert%26Delete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Insert

# %%
import pandas as pd

var = pd.DataFrame({"A":[1,2,3,4,5],
                    "B":[6,7,8,9,10]})

var
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
var.insert(1,"C",var["A"])
var
# Out:
#    A  C   B
# 0  1  1   6
# 1  2  2   7
# 2  3  3   8
# 3  4  4   9
# 4  5  5  10

# %%
var.insert(1,"D",[11,12,13,14,15]) #No of values should match with the no of values present in the index

var
# Out:
#    A   D  C   B
# 0  1  11  1   6
# 1  2  12  2   7
# 2  3  13  3   8
# 3  4  14  4   9
# 4  5  15  5  10

# %%
var["E"] = var["A"][:3] #inserting values to a certain value, 1-3

var
# Out:
#    A   D  C   B    E
# 0  1  11  1   6  1.0
# 1  2  12  2   7  2.0
# 2  3  13  3   8  3.0
# 3  4  14  4   9  NaN
# 4  5  15  5  10  NaN

# %% [markdown]
# DELETE

# %%
var1 = var.pop("B")

var1
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# Name: B, dtype: int64

# %%
var
# Out:
#    A   D  C    E
# 0  1  11  1  1.0
# 1  2  12  2  2.0
# 2  3  13  3  3.0
# 3  4  14  4  NaN
# 4  5  15  5  NaN

# %%
del var["C"]

var
# Out:
#    A   D    E
# 0  1  11  1.0
# 1  2  12  2.0
# 2  3  13  3.0
# 3  4  14  NaN
# 4  5  15  NaN
